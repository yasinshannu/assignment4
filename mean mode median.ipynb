# %%
import matplotlib.pyplot as plt
x=1,23,4,56,34,54,34,56,4
y=23,4,5,66,44,66,44,45,6
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=1,23,4,56,34,54,34,56,4
y=23,4,5,66,44,66,44,45,6
plt.scatter(x,y,marker="*")
plt.show()

# %%
import matplotlib.pyplot as plt
x=1,23,4,56,34,54,34,56,4
y=23,4,5,66,44,66,44,45,6
plt.scatter(x,y,marker=">")
plt.show()

# %%
import matplotlib.pyplot as plt
x=1,23,4,56,34,54,34,56,4
y=23,4,5,66,44,66,44,45,6
plt.scatter(x,y,marker="<")
plt.show()

# %%
import matplotlib.pyplot as plt
x=1,23,4,56,34,54,34,56,4
y=23,4,5,66,44,66,44,45,6
plt.scatter(x,y,marker="s")
plt.show()

# %%
import matplotlib.pyplot as plt
x=1,23,4,56,34,54,34,56,4
y=23,4,5,66,44,66,44,45,6
plt.scatter(x,y,marker="o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)
colors=np.random.rand(50)
plt.scatter(x,y,s=z*100,c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(500)
y=np.random.rand(500)
z=np.random.rand(500)
colors=np.random.rand(500)
plt.scatter(x,y,s=z*10,c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)
colors=np.random.rand(50)
plt.scatter(x,y,s=z*100,c=colors,alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)
colors=np.random.rand(50)
plt.scatter(x,y,s=z*100,marker="*",c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)
colors=np.random.rand(50)
plt.scatter(x,y,s=z*100,marker="s",c=colors,alpha=0.8)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)
colors=np.random.rand(50)
plt.scatter(x,y,s=z*100,marker="<",c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as py
x=1,23,4,56,34,54,34,56,4
y=23,4,5,66,44,66,44,45,6
z=(x,y)
plt.boxplot(z)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x164beb7da50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x164beb067d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x164beb7f010>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x164beb066e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x164beb058d0>,
# ...
#  'means': []}

# %%
import pandas as pd
import numpy as py
df=pd.DataFrame(np.random.rand(10,5),columns=['A','B','C','D','E'])
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import numpy as py
x=1,3,2,4,6
y=1,3,20,4,6
z=(x,y)
plt.boxplot(z)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x240e05b8310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x240e05b88b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x240e05b8040>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x240e05b8e50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x240e05b9120>,
# ...
#  'means': []}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)
df=pd.DataFrame(np.random.rand(10,5)*10)
df.plot.box()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)
df=pd.DataFrame(np.random.rand(10,5)*10)
df.plot.box()
plt.show()

# %%
import matplotlib.pyplot as plt
x=12,23,4,22,32,23
y=12.23,34,24,34,42,3
plt.scatter(x,y)
plt.show()
