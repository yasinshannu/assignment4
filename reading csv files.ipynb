# %%
import pandas as pd
df=pd.read_csv("IPL IMB381IPL2013.csv")
df

# %%
df.head(10)
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# ...

# %%
df.tail(10)
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 120     121     Vettori, DL    2      NZ    DD+   Allrounder    4486     359
# 121     122  Vinay Kumar, R    2     IND   RCB+       Bowler      11       1
# 122     123       Warne, SK    3     AUS     RR       Bowler    3154     708
# 123     124      Warner, DA    1     AUS     DD      Batsman     483       2
# 124     125       White, CL    2     AUS   RCB+      Batsman     146       5
# 125     126       Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127     Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128    Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129     Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130      Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
df.sample(10)
# Out:
#      Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 28       29  Gilchrist, AC    3     AUS   DC+    W. Keeper    5570       0
# 110     111   Taylor, LRPL    2      NZ  RCB+      Batsman    2742       2
# 46       47    Kamran Khan    1     IND   RR+       Bowler       0       0
# 49       50     Katich, SM    3     AUS  KXIP      Batsman    4188      21
# 2         3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 26       27      Gayle, CH    2      WI  KKR+   Allrounder    6373      72
# 57       58    Malinga, SL    2      SL    MI       Bowler     275     101
# 56       57   Maharoof, MF    2      SL    DD   Allrounder     556      25
# 29       30       Gony, MS    2     IND  CSK+       Bowler       0       0
# 101     102      Singh, RP    2     IND   DC+       Bowler     116      40
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
list(df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
df.head(5).transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
df.shape
# Out:
# (130, 26)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df[0:8]
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# ...

# %%
df.transpose
# Out:
# <bound method DataFrame.transpose of      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df['PLAYER NAME'][0:5]
# Out:
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# Name: PLAYER NAME, dtype: object

# %%
df.transpose
# Out:
# <bound method DataFrame.transpose of      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df.iloc[9:19, 1:19]
# Out:
#         PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 9       Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
# 10        Bravo, DJ    2      WI   MI+   Allrounder    2200      86
# 11   Chanderpaul, S    3      WI   RCB      Batsman    9918       9
# 12       Chawla, PP    1     IND  KXIP   Allrounder       5       3
# 13  de Villiers, AB    2      SA   DD+    W. Keeper    5457       2
# 14        Dhawan, S    2     IND   MI+      Batsman       0       0
# 15        Dhoni, MS    2     IND   CSK    W. Keeper    3509       0
# 16      Dilshan, TM    2      SL   DD+   Allrounder    4722      32
# 17        Dinda, AB    2     IND  KKR+       Bowler       0       0
# 18       Dravid, RS    3     IND  RCB+      Batsman   13288       1
#
#     ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  CAPTAINCY EXP  RUNS-S   HS  \
# 9         4686     84.76         0        0.0              1     394   50
# ...

# %%
df.COUNTRY.value_counts()
# Out:
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: COUNTRY, dtype: int64

# %%
df.AGE.value_counts(normalize=True)*100
# Out:
# 2    66.153846
# 3    21.538462
# 1    12.307692
# Name: AGE, dtype: float64

# %%
import pandas as pd
df=pd.read_csv("bollywood.csv")
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
print(df[['Genre','MovieName']])
# Out:
#          Genre                    MovieName
# 0      Romance                     2 States
# 1    Thriller                  Table No. 21
# 2       Comedy           Amit Sahni Ki List
# 3       Drama              Rajdhani Express
# 4       Comedy                 Bobby Jasoos
# ..         ...                          ...
# 144     Comedy           Dum Laga Ke Haisha
# 145   Thriller                         NH10
# 146     Comedy  Dilliwali Zaalim Girlfriend
# 147     Comedy                     Hunterrr
# 148     Action                Kochadaiiyaan
#
# [149 rows x 2 columns]

# %%
df[df["Genre"]=="Comedy"]
# Out:
#      SlNo Release Date                    MovieName ReleaseTime   Genre  \
# 2       3    18-Jul-14           Amit Sahni Ki List           N  Comedy
# 4       5     4-Jul-14                 Bobby Jasoos           N  Comedy
# 6       7    19-Sep-14                Daawat-E-Ishq           N  Comedy
# 7       8    11-Jan-13   Matru Ki Bijlee Ka Mandola           N  Comedy
# 8       9    10-Jan-14                 Dedh Ishqiya          LW  Comedy
# 14     15     8-Aug-14                Entertainment           N  Comedy
# 17     18     6-Jun-14                   Filmistaan          HS  Comedy
# 18     19    12-Sep-14                Finding Fanny           N  Comedy
# 19     20    13-Jun-14                        Fugly          HS  Comedy
# 39     40    20-Jun-14                   Humshakals          HS  Comedy
# 46     47    15-Mar-13           Mere Dad Ki Maruti           N  Comedy
# 47     48    15-Mar-13                    Jolly LLB           N  Comedy
# ...

# %%
df[df["Genre"]=="Thriller"]
# Out:
#      SlNo Release Date                             MovieName ReleaseTime  \
# 28     29    18-Jul-14                          Hate Story 2           N
# 30     31     7-Feb-14                             Heartless           N
# 31     32    15-Feb-13                              Murder 3          FS
# 38     39     1-Mar-13                  The Attacks of 26/11           N
# 44     45    15-Mar-13                                    3G           N
# 51     52    22-Mar-13                                 Aatma           N
# 53     54    22-Mar-13                              Sona Spa           N
# 62     63    19-Apr-13                         Ek Thi Daayan          FS
# 68     69     3-May-13                    Shootout at Wadala           N
# 71     72    21-Mar-14                          Ragini MMS 2           N
# 73     74    29-Aug-14                        Raja Natwarlal           N
# 88     89    28-Nov-14                                   Zid           N
# ...

# %%
df[df["Genre"]=="Action"]
# Out:
#      SlNo Release Date                MovieName ReleaseTime   Genre  Budget  \
# 15     16    18-Jan-13                  Bandook           N  Action       4
# 22     23    14-Feb-14                   Gunday           N  Action      50
# 35     36    22-Feb-13          Zilla Ghaziabad           N  Action      36
# 36     37     6-Jun-14                  Holiday          HS  Action      50
# 41     42    24-Jan-14                   Jai Ho           N  Action     120
# 43     44    25-Jul-14                     Kick           N  Action     100
# 48     49     9-May-14             Koyelaanchal          HS  Action       8
# 54     55    29-Mar-13               Himmatwala           N  Action      50
# 61     62    12-Apr-13  Commando-A One Man Army          LW  Action      22
# 77     78     3-Jan-14                Sholay 3D           N  Action      25
# 78     79    15-Aug-14          Singham Returns          LW  Action      90
# ...

# %%
df[df["Budget"]<=100]
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 143   144    20-Feb-15                     Badlapur          FS     Action
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
#
# ...

# %%
df[df['ReleaseTime']=='HS']
# Out:
#      SlNo Release Date             MovieName ReleaseTime     Genre  Budget  \
# 5       6    30-May-14            Citylights          HS    Drama        7
# 12     13    27-Jun-14            Ek Villain          HS   Romance      35
# 17     18     6-Jun-14            Filmistaan          HS    Comedy      10
# 19     20    13-Jun-14                 Fugly          HS    Comedy      10
# 29     30     9-May-14          Hawaa Hawaai          HS    Drama       11
# 32     33    23-May-14             Heropanti          HS   Romance      21
# 36     37     6-Jun-14               Holiday          HS    Action      50
# 39     40    20-Jun-14            Humshakals          HS    Comedy      75
# 48     49     9-May-14          Koyelaanchal          HS    Action       8
# 49     50     2-May-14  Kya Dilli Kya Lahore          HS    Drama        7
# 55     56     9-May-14             Manjunath          HS    Drama        3
# ...

# %%
df[df['YoutubeViews']>=10000]
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
df[df['YoutubeLikes']>=10000]
# Out:
#      SlNo Release Date                  MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                   2 States          LW    Romance
# 12     13    27-Jun-14                 Ek Villain          HS    Romance
# 14     15     8-Aug-14              Entertainment           N     Comedy
# 16     17    25-Jan-13                     Race 2          LW  Thriller
# 18     19    12-Sep-14              Finding Fanny           N     Comedy
# 21     22     7-Mar-14                Gulaab Gang           N    Action
# 23     24     2-Oct-14                     Haider          FS     Drama
# 26     27    24-Oct-14             Happy New Year          LW     Drama
# 27     28     8-Feb-13  ABCD _ Any Body Can Dance           N     Drama
# 28     29    18-Jul-14               Hate Story 2           N   Thriller
# 36     37     6-Jun-14                    Holiday          HS     Action
# 37     38    11-Jul-14  Humpty Sharma Ki Dulhania           N    Romance
# ...

# %%
for i in range(len(df["Release Date"])):
    print([df.loc[i,"Release Date"][-2:]])
# Out:
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['14']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['13']
# ['13']
# ['14']
# ['14']
# ['14']
# ['13']
# ['14']
# ['14']
# ['14']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['14']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['14']
# ['14']
# ['13']
# ['14']
# ['13']
# ['13']
# ['14']
# ['14']
# ['14']
# ['13']
# ['14']
# ['13']
# ['13']
# ['14']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['13']
# ['13']
# ['14']
# ['13']
# ['14']
# ['14']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['14']
# ['14']
# ['13']
# ['14']
# ['14']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ['14']
# ['13']
# ['14']
# ['14']
# ['13']
# ['14']
# ['14']
# ['13']
# ['14']
# ['13']
# ['13']
# ['13']
# ['14']
# ['14']
# ['13']
# ['13']
# ['14']
# ['14']
# ['13']
# ['13']
# ['14']
# ['13']
# ['14']
# ['13']
# ['14']
# ...

# %%
for i in range(len(df["Release Date"])):
    print(df.loc[i,"Release Date"][-6:-3])
# Out:
# Apr
# Jan
# Jul
# Jan
# Jul
# May
# Sep
# Jan
# Jan
# Jan
# Mar
# Jan
# Jun
# Jan
# Aug
# Jan
# Jan
# Jun
# Sep
# Jun
# Feb
# Mar
# Feb
# Oct
# Nov
# Feb
# Oct
# Feb
# Jul
# May
# Feb
# Feb
# May
# Feb
# Feb
# Feb
# Jun
# Jul
# Mar
# Jun
# Mar
# Jan
# Sep
# Jul
# Mar
# Nov
# Mar
# Mar
# May
# May
# Jul
# Mar
# Apr
# Mar
# Mar
# May
# Aug
# Apr
# Sep
# Apr
# May
# Apr
# Apr
# Jan
# Apr
# Mar
# Jan
# May
# May
# Mar
# May
# Mar
# May
# Aug
# Apr
# Feb
# May
# Jan
# Aug
# Nov
# May
# Nov
# May
# Jan
# Jun
# May
# Mar
# Jun
# Nov
# Dec
# Jun
# Dec
# Oct
# Jun
# Sep
# Jun
# Oct
# Jul
# Jul
# May
# Jul
# Jul
# Apr
# Apr
# Jul
# Jul
# Mar
# Jul
# Feb
# Jul
# Feb
# Jul
# Jan
# Jul
# Apr
# Aug
# Aug
# Aug
# Aug
# Nov
# Mar
# Nov
# Nov
# Nov
# Nov
# Oct
# Oct
# Oct
# Oct
# Oct
# Sep
# Sep
# Sep
# May
# Sep
# Sep
# Jan
# Jan
# Jan
# Jan
# Jan
# Feb
# Feb
# Feb
# Feb
# Mar
# Mar
# Mar
# May
